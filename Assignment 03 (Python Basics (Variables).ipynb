# %% [markdown]
# ## Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Abdul Hadi\tAli Akbar\n 01-01-2012")
# Out:
# Abdul Hadi	Ali Akbar
#  01-01-2012

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = input("Enter your name: ")
print(name)

age = input("Enter your age: ")
print(age)

education= input("Enter your education: ")
print(education)


city = input("Enter your city: ")
print(city)

hobby = input("Enter your hobby: ")
print(hobby)
# Out:
# hadi
# 16
# inermidiate
# karachi
# playing cricket

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %% [markdown]
# | Operator | Meaning                  | Example  | Output |
# | -------- | ------------------------ | -------- | ------ |
# | `==`     | Equal to                 | `5 == 5` | `True` |
# | `!=`     | Not equal to             | `5 != 3` | `True` |
# | `>`      | Greater than             | `10 > 5` | `True` |
# | `<`      | Less than                | `3 < 7`  | `True` |
# | `>=`     | Greater than or equal to | `5 >= 5` | `True` |
# | `<=`     | Less than or equal to    | `4 <= 6` | `True` |

# %% [markdown]
# 4. Completes the following steps of small task:
# Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
# Mention Variable of Total Marks and assign 300 to it
# Calculate Percentage

# %%
def calculate_percentage(english_marks, bio_marks, maths_marks):
    total_marks = 300
    obtained_marks = english_marks + bio_marks + maths_marks
    percentage = (obtained_marks / total_marks) * 100

    print("Percentage:", percentage, "%")

# %%
calculate_percentage(77, 85, 56)
# Out:
# Percentage: 72.66666666666667 %
